# %% [markdown]
# <a href="https://colab.research.google.com/github/manojsankarkumar/manojsankarkumar.github.io/blob/master/Advanced_Python_Programming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1. Different techniques of print statement
print("My name is Manoj Kumar")

print("He said, I'm John's learner")

print("""I'can't think of any lines at the moment, that could extend beyond 2 to 3 line,
so I decided to type in anything that I like here""")
# Out:
# My name is Manoj Kumar
# He said, I'm John's learner
# I'can't think of any lines at the moment, that could extend beyond 2 to 3 line,
# so I decide to type in anything that I like here

# %%
#Creating a variable

item_to_buy = "Tomato", "Strawberry"

print(item_to_buy)

average_grade = 6.5
average_grade

type(average_grade)
# Out:
# ('Tomato', 'Strawberry')
# float

# %%
#2.2 String Concatenation - Indexing & Slicing

fname = "Manoj"
lname = "Kumar"
age = 33

print(fname + ' ' + lname + '_' + str(age)) #An operation is performed

print(fname,lname,age) #It just prints
# Out:
# Manoj Kumar_33
# Manoj Kumar 33
