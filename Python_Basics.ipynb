# %% [markdown]
# <a href="https://colab.research.google.com/github/manojsankarkumar/manojsankarkumar.github.io/blob/master/Python_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # New Section

# %%
## Level 1. Print if the guessed number is right or not
secret_number = 56
user_input = int(input('Enter the number: '))

if secret_number == user_input:
  print("You're guess is right")
else:
  print('Your guess is wrong')
# Out:
# Enter the number: 56
# You're guess is right

# %%
## Level 2. Print if the guessed number is right or not but with maximum of 7 tries
secret_number = 56

for i in range(0,7):
  user_input = int(input('Enter the number: '))

  if secret_number == user_input:
    print("You're guess is right")
    break
  else:
    print('Your guess is wrong')
# Out:
# Enter the number: 56
# You're guess is right

# %%
## Level 2. While loop - when end number is not defined and code to execute infinite times
secret_number = 56

while True:
  user_input = int(input('Enter the number: '))

  if secret_number == user_input:
    print("You're guess is right")
    break
  else:
    print('Your guess is wrong')
# Out:
# Enter the number: 56
# You're guess is right

# %%
## Level 3. Give multiple conditions
#1. User should enter the number between 1-100. If it's entered wrong, the program should say, "Invalid Number"
#2. If the user guessed number > secret number, then program should say, "Your number is greater than secret number"
#3. If the user guessed number < secret number, then program should say, "Your number is lesser than secret number"


print("Welcome to Number Guessing Game!!!")
print('Guess the number between 1 and 100')

secret_number = 98

for i in range(0,7):
  user_input = int(input("Enter the number:"))
  if user_input < 1 or user_input > 100:
    print("Invalid number! Enter the number between 1 and 100")
  elif user_input > secret_number:
    print("Your number is higher")
  elif user_input < secret_number:
    print("Your number is lesser")
  else:
    print("Your guessed number is correct!")
    break
# Out:
# Welcome to Number Guessing Game!!!
# Guess the number between 1 and 100
# Enter the number:98
# Your guessed number is correct!
