# %% [markdown]
# <a href="https://colab.research.google.com/github/manojsankarkumar/manojsankarkumar.github.io/blob/master/Task_1_Python_Programming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Task 1 - Give 2 examples of all string functions which should be meaningful

# %%
#capitalize()	Converts the first character to upper case
user_name = "manoj kumar"
print(user_name.capitalize())

car_name = "suzuki swift"
print(car_name.capitalize())
# Out:
# Manoj kumar
# Suzuki swift

# %%
# casefold()	Converts string into lower case

city_name = "NEW DELHI"
print(city_name.casefold())

town_name = "SALEM"
print(town_name.casefold())
# Out:
# new delhi
# salem

# %%
# center()	Returns a centered string
word = "course"
print(word.center(20,'-'))

word_1 = "automatic"
print(word_1.center(10,"_"))
# Out:
# -------course-------
# automatic_

# %%
# count()	Returns the number of times a specified value occurs in a string
country_name = 'Australia'
print(country_name.count('a'))

city_name = "Canberra"
print(city_name.count('r'))
# Out:
# 2
# 2

# %%
# encode()	Returns an encoded version of the string
given_name = "My name is Månoj Kumar"
print(given_name.encode(encoding='ascii',errors='replace'))

firs_name = "My name is Råm Kumar"
print(given_name.encode(encoding='ascii',errors='ignore'))
# Out:
# b'My name is M?noj Kumar'
# b'My name is Mnoj Kumar'

# %%
# endswith()	Returns true if the string ends with the specified value
place_name = "Brisbane"
print(place_name.endswith('a'))

village = "Korattur"
print(village.endswith("r"))
# Out:
# False
# True

# %%
# expandtabs()	Sets the tab size of the string
car_model = "H\to\tn\td\ta"
print(car_model.expandtabs())

fuel = "P\te\tt\tr\to\tl\t"
print(fuel.expandtabs())
# Out:
# H       o       n       d       a
# P       e       t       r       o       l

# %%
# find()	Searches the string for a specified value and returns the position of where it was found
sentence = "The mountain is huge and looks massive"
print(sentence.find("huge"))

hospital = "Velammal"
print(hospital.find("V"))
# Out:
# 16
# 0

# %%
# format()	Formats specified values in a string
print("My name is {}, and I am from {}".format("Manoj","Chennai"))
print("I find this {}".format("Interesting"))
# Out:
# My name is Manoj, and I am from Chennai
# I find this Interesting

# %%
# format_map()	Formats specified values from a dictionary in a string
my_detail = {"name" : "MK", "age" : 26}
sample_sentence = "Happy birthday {name} you are now on level {age}!"
print(sample_sentence.format_map(my_detail))

student_detail = {"name" : "MK", "course" : "DS-ML-AI"}
sample_sentence_1 = "{name} is enrolled on {course} course"
print(sample_sentence_1.format_map(student_detail))
# Out:
# Happy birthday MK you are now on level 26!
# MK is enrolled on DS-ML-AI course

# %%
# index()	Searches the string for a specified value and returns the position of where it was found
student_subject_review = "Maths is difficult"
print(student_subject_review.index("u"))

mobile = "samsung"
print(mobile.index("g"))
# Out:
# 15
# 6

# %%
# isalnum()	Returns True if all characters in the string are alphanumeric
string = "Company"
print(string.isalnum())

string_1 = "456 "
print(string_1.isalnum())
# Out:
# True
# False

# %%
# isalpha()	Returns True if all characters in the string are in the alphabet
city = "Area 52"
print(city.isalpha())

country = "America"
print(country.isalpha())
# Out:
# False
# True

# %%
# isascii()	Returns True if all characters in the string are ascii characters
name = "Manoj"
print(name.isascii())

score = "321"
print(score.isascii())
# Out:
# True
# True

# %%
# isdecimal()	Returns True if all characters in the string are decimals
score = "123"
print(score.isdecimal())

point = "5.6"
print(point.isdecimal())
# Out:
# True
# False

# %%
# isdigit()	Returns True if all characters in the string are digits
points = "34678"
print(points.isdigit())

player = "Dhoni"
print(player.isdigit())
# Out:
# True
# False

# %%
# isidentifier()	Returns True if the string is an identifier
security_key = "Password"
print(security_key.isidentifier())

password = "1234password"
print(password.isidentifier())
# Out:
# True
# False

# %%
# islower()	Returns True if all characters in the string are lower case
state_name = "TAMILNADU"
print(state_name.islower())

country = "argentina"
print(country.islower())
# Out:
# False
# True

# %%
# isnumeric()	Returns True if all characters in the string are numeric
bus_no = "25"
print(bus_no.isnumeric())

train_no = "SL4567"
print(train_no.isnumeric())
# Out:
# True
# False

# %%
# isprintable()	Returns True if all characters in the string are printable
string = "Roshan Arts"
print(string.isprintable())

string_1 = "Roshan #B\n"
print(string_1.isprintable())
# Out:
# True
# False

# %%
# isspace()	Returns True if all characters in the string are whitespaces
shopping_mall = 'Spencer   Plaza   '
print(shopping_mall.isspace())

book = "         "
print(book.isspace())
# Out:
# False
# True

# %%
# istitle()	Returns True if the string follows the rules of a title
statement = "I Am Interested On Cars"
print(statement.istitle())

statement_1 = "are you feeling ok?"
print(statement_1.istitle())
# Out:
# True
# False

# %%
# isupper()	Returns True if all characters in the string are upper case
state_name = "WESTERN GHATS"
print(state_name.isupper())

place_name = "madurai"
print(place_name.isupper())
# Out:
# True
# False

# %%
# join()	Converts the elements of an iterable into a string
tuple = ("M","A","N","O","J")
print("".join(tuple))

tuple1 = ("K","U","M","A","R")
print("".join(tuple1))
# Out:
# MANOJ
# KUMAR

# %%
# ljust()	Returns a left justified version of the string
fruit = "banana"
print(fruit.ljust(10, "O"))

name = "igl"
print(name.ljust(5,"o"))
# Out:
# bananaOOOO
# igloo

# %%
# lower()	Converts a string into lower case
state_name = "DHARMAPURI"
print(state_name.lower())

country = "JAPAN"
print(country.lower())
# Out:
# dharmapuri
# japan

# %%
# lstrip()	Returns a left trim version of the string
name = "     madurai"
print(name.lstrip())

word = "   important"
print(word.lstrip())
# Out:
# madurai
# important

# %%
# maketrans()	Returns a translation table to be used in translations
statement = "Hello All!"
modified_statement = str.maketrans("H", "C")
print(statement.translate(modified_statement))

statement_1 = "Congratulations"
modified_statement_1 = str.maketrans("s", " ")
print(statement_1.translate(modified_statement_1))
# Out:
# Cello All!
# Congratulation

# %%
# partition()	Returns a tuple where the string is parted into three parts
sentence = "I practice coding 1 hour per day"
print(sentence.partition("coding"))

highways = "NH India has longest roadways"
print(highways.partition("has"))
# Out:
# ('I practice ', 'coding', ' 1 hour per day')
# ('NH India ', 'has', ' longest roadways')

# %%
# replace()	Returns a string where a specified value is replaced with a specified value
destination = "Ooty has 14 hairpin bends"
print(destination.replace("14","26"))

destination_1 = "Coimbatore is usually hot"
print(destination_1.replace("Coimbatore","Chennai"))
# Out:
# Ooty has 26 hairpin bends
# Chennai is usually hot

# %%
# rfind()	Searches the string for a specified value and returns the last position of where it was found
manufacturer = "Honeywell"
print(manufacturer.rfind("l"))

manufacturer_1 = "Ramraj"
print(manufacturer_1.rfind("R"))
# Out:
# 8
# 0

# %%
# rindex()	Searches the string for a specified value and returns the last position of where it was found
language = "MALAYALAM"
print(language.rindex("L"))

cuisine = "Chinese"
print(cuisine.rindex("s"))
# Out:
# 6
# 5

# %%
# rjust()	Returns a right justified version of the string
fruit = "orange"
print(fruit.rjust(20,"*"))

vegetable = "brinjal"
print(vegetable.rjust(10,"*"))
# Out:
# **************orange
# ***brinjal

# %%
# rpartition()	Returns a tuple where the string is parted into three parts
hobby = "I can drive as long as possible"
print(hobby.rpartition("drive"))

sports = "I don't watch cricket or any other form of sports"
print(sports.rpartition("watch"))
# Out:
# ('I can ', 'drive', ' as long as possible')
# ("I don't ", 'watch', ' cricket or any other form of sports')

# %%
# rsplit()	Splits the string at the specified separator, and returns a list
list = "honda, toyota, suzuki"
print(list.rsplit(", "))

friends = "ram, sam, sony"
print(friends.rsplit(", "))
# Out:
# ['honda', 'toyota', 'suzuki']
# ['ram', 'sam', 'sony']

# %%
# rstrip()	Returns a right trim version of the string
name = "Thirupathi     "
print(name.rstrip())

sea_name = "Indian Ocean   "
print(sea_name.rstrip())
# Out:
# Thirupathi
# Indian Ocean

# %%
# split()	Splits the string at the specified separator, and returns a list
statement = "welcome to the wonderful place"
print(statement.split(" "))

statement_1 = "Hi, we welcome you, all"
print(statement_1.split(","))
# Out:
# ['welcome', 'to', 'the', 'wonderful', 'place']
# ['Hi', ' we welcome you', ' all']

# %%
# splitlines()	Splits the string at line breaks and returns a list
sample_text = "The passage quoted is not a sentence\nThe passage consists of a sentence of sixty-six words\nthen a sequence of clauses"
print(sample_text.splitlines())

sentence = "The sentence\n could be anything consisting of multiple words that provide a\nmeaning"
print(sentence.splitlines())
# Out:
# ['The passage quoted is not a sentence', 'The passage consists of a sentence of sixty-six words', 'then a sequence of clauses']
# ['The sentence', ' could be anything consisting of multiple words that provide a', 'meaning']

# %%
# startswith()	Returns true if the string starts with the specified value
airport_name = "Anna International Airport"
print(airport_name.startswith("A"))

flight = "Indian Airlines"
print(flight.startswith("a"))
# Out:
# True
# False

# %%
# strip()	Returns a trimmed version of the string
fruit = "         Banana        "
print(fruit.strip())

place = "Tuticorin     "
print(place.strip())
# Out:
# Banana
# Tuticorin

# %%
# swapcase()	Swaps cases, lower case becomes upper case and vice versa
state = "tamilnadu"
print(state.swapcase())

motorbike = "YAMAHA"
print(motorbike.swapcase())
# Out:
# TAMILNADU
# yamaha

# %%
# title()	Converts the first character of each word to upper case
show_title = "magic show"
print(show_title.title())

address = "yercaud"
print(address.title())
# Out:
# Magic Show
# Yercaud

# %%
# translate()	Returns a translated string
statement = "Hello All!"
modified_statement = str.maketrans("H", "C")
print(statement.translate(modified_statement))

statement_1 = "Congratulations"
modified_statement_1 = str.maketrans("s", " ")
print(statement_1.translate(modified_statement_1))
# Out:
# Cello All!
# Congratulation
